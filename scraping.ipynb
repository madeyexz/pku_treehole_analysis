# %%
import pandas as pd
import os
import re
import time
import random
import json
import datetime
import requests

def get_content(id,page):
    headers = {
        'authorization':
          'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..wYhkknD8m4HFgr1ZGNX2ZbV3sABzGujPvMZGO8t1gzY',
        'method':
            'GET',
        'Host':
            'treehole.pku.edu.cn',
        'Referer':
            'https://treehole.pku.edu.cn/web/',
        'Accept':
            'application/json, text/plain, */*',
        'Accept-Encoding':
            'gzip, deflate, br, zstd',
        'Accept-Language':
            'zh-CN,zh;q=0.9',
        'Cookie':
            '',
        'Sec-Ch-Ua':
            '"Chromium";v="118", "Google Chrome";v="118", "Not=A?Brand";v="99"',
        'Sec-Ch-Ua-Mobile':
            '?0',
        'Sec-Ch-Ua-Platform':
            '"Windows"',
        'Sec-Fetch-Dest':
            'document',
        'Sec-Fetch-Mode':
            'navigate',
        'Uuid':
            'Web_PKUHOLE_2.0.0_WEB_UUID_eb6fd731-9ddf-46db-b1aa-40a52ebfc42a',
        'Sec-Fetch-User':
            '?1',
        'x-xsrf-token':
          '',
        'User-Agent':
            'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/118.0.0.0 Safari/537.36'}

    url = f'https://treehole.pku.edu.cn/api/pku_hole?limit=75&keyword=gsm&page={page}'

    r1 = requests.get(url, headers=headers)
    j1 = json.loads(r1.text)
    #print(j1)
    return j1['data']['data']

list1 = []
columns = ['pid', 'time', 'reply', 'text']
result1 = pd.DataFrame(columns=columns)

import logging

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler('scraping.log'),
        logging.StreamHandler()
    ]
)

for i in range(0, 100000):
    logging.info(f'Starting iteration {i}')
    d = get_content(i,i)
    random_sleep = random.randint(3, 6)
    logging.info(f'Sleeping for {random_sleep} seconds')
    time.sleep(random_sleep)
    
    logging.info(f'Processing {len(d)} items from page {i}')
    for item in d:
        time2 = datetime.datetime.fromtimestamp(item['timestamp'])
        ILLEGAL_CHARACTERS_RE = re.compile(r'[\000-\010]|[\013-\014]|[\016-\037]')
        text = ILLEGAL_CHARACTERS_RE.sub(r'', str(item['text']))
        c = [item['pid'], time2, item['reply'], text]
        list1.append(c)

    temp_df = pd.DataFrame(list1, columns=columns)
    result1 = pd.concat([result1, temp_df], ignore_index=True)
    logging.info(f'Added {len(temp_df)} rows to DataFrame')
    logging.info(f'Current DataFrame has {len(result1)} total rows')
    if not result1.empty:
        sample_row = result1.iloc[-1]  # Get the last added row
        logging.info(f'Latest entry - PID: {sample_row["pid"]}, Time: {sample_row["time"]}, '
                    f'Reply count: {sample_row["reply"]}, Text preview: {sample_row["text"][:100]}...')
    logging.info(f'Saved data to CSV file')
    
    list1 = []
    logging.info(f'Completed iteration {i}\n')
# ... rest of the code remains same ...
# Move this outside the loop
result1.to_csv('pku_treehole_data_gsm.csv', index=False)
# Out:
# 2024-11-06 13:02:21,925 - INFO - Starting iteration 0
# 2024-11-06 13:02:22,557 - INFO - Sleeping for 4 seconds
# 2024-11-06 13:02:26,560 - INFO - Processing 75 items from page 0
# C:\Users\12875\AppData\Local\Temp\ipykernel_19628\4276611513.py:86: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   result1 = pd.concat([result1, temp_df], ignore_index=True)
# 2024-11-06 13:02:26,566 - INFO - Added 75 rows to DataFrame
# 2024-11-06 13:02:26,568 - INFO - Current DataFrame has 75 total rows
# 2024-11-06 13:02:26,570 - INFO - Latest entry - PID: 6808508, Time: 2024-11-02 11:48:07, Reply count: 0, Text preview: 6795146
# 捞捞 有人在中兴大厦工区吗
# gsm jy xk sms 字节跳动...
# 2024-11-06 13:02:26,571 - INFO - Saved data to CSV file
# ...

# %%
result1.to_csv('pku_treehole_data_gsm.csv', index=False)
result1.shape
# Out:
# (4753, 4)
